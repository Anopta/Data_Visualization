# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
sns.set(color_codes=True)

# %%
df=pd.read_csv('test.csv')

# %%
df
# Out:
#               date_time is_holiday  air_pollution_index  humidity  wind_speed  \
# 0      18-05-2017 00:00       None                 73.0      63.0         1.0
# 1      18-05-2017 00:00       None                251.0      63.0         1.0
# 2      18-05-2017 00:00       None                 75.0      56.0         1.0
# 3      18-05-2017 01:00       None                 98.0      56.0         1.0
# 4      18-05-2017 01:00       None                283.0      56.0         1.0
# ...                 ...        ...                  ...       ...         ...
# 14449               NaN        NaN                  NaN       NaN         NaN
# 14450               NaN        NaN                  NaN       NaN         NaN
# 14451               NaN        NaN                  NaN       NaN         NaN
# 14452               NaN        NaN                  NaN       NaN         NaN
# 14453               NaN        NaN                  NaN       NaN         NaN
#
# ...

# %%
df.columns
# Out:
# Index(['date_time', 'is_holiday', 'air_pollution_index', 'humidity',
#        'wind_speed', 'wind_direction', 'visibility_in_miles', 'dew_point',
#        'temperature', 'rain_p_h', 'snow_p_h', 'clouds_all', 'weather_type',
#        'weather_description'],
#       dtype='object')

# %%
df.values
# Out:
# array([['18-05-2017 00:00', 'None', 73.0, ..., 90.0, 'Rain',
#         'moderate rain'],
#        ['18-05-2017 00:00', 'None', 251.0, ..., 90.0, 'Mist', 'mist'],
#        ['18-05-2017 00:00', 'None', 75.0, ..., 90.0, 'Drizzle',
#         'light intensity drizzle'],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=14454, step=1)

# %%
df.shape
# Out:
# (14454, 14)

# %%
df.describe()
# Out:
#        air_pollution_index    humidity  wind_speed  wind_direction  \
# count           199.000000  199.000000  199.000000      199.000000
# mean            154.130653   75.778894    2.407035      216.075377
# std              83.713997   14.921050    1.657597       91.932833
# min              10.000000   25.000000    0.000000        0.000000
# 25%              83.000000   64.000000    1.000000      164.000000
# 50%             154.000000   75.000000    2.000000      205.000000
# 75%             231.500000   88.500000    4.000000      302.000000
# max             298.000000  100.000000   10.000000      355.000000
#
#        visibility_in_miles   dew_point  temperature  rain_p_h  snow_p_h  \
# count           199.000000  199.000000   199.000000     199.0     199.0
# mean              5.236181    5.236181   282.633216       0.0       0.0
# std               2.702318    2.702318     2.311407       0.0       0.0
# min               1.000000    1.000000   279.020000       0.0       0.0
# ...

# %%
df.head()
# Out:
#           date_time is_holiday  air_pollution_index  humidity  wind_speed  \
# 0  18-05-2017 00:00       None                 73.0      63.0         1.0
# 1  18-05-2017 00:00       None                251.0      63.0         1.0
# 2  18-05-2017 00:00       None                 75.0      56.0         1.0
# 3  18-05-2017 01:00       None                 98.0      56.0         1.0
# 4  18-05-2017 01:00       None                283.0      56.0         1.0
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0            27.0                  4.0        4.0       285.15       0.0
# 1            27.0                  4.0        4.0       285.15       0.0
# 2             0.0                  1.0        1.0       285.15       0.0
# 3           351.0                  2.0        2.0       284.79       0.0
# 4           351.0                  1.0        1.0       284.79       0.0
#
#    snow_p_h  clouds_all weather_type      weather_description
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14454 entries, 0 to 14453
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date_time            199 non-null    object
#  1   is_holiday           199 non-null    object
#  2   air_pollution_index  199 non-null    float64
#  3   humidity             199 non-null    float64
#  4   wind_speed           199 non-null    float64
#  5   wind_direction       199 non-null    float64
#  6   visibility_in_miles  199 non-null    float64
#  7   dew_point            199 non-null    float64
#  8   temperature          199 non-null    float64
#  9   rain_p_h             199 non-null    float64
#  10  snow_p_h             199 non-null    float64
#  11  clouds_all           199 non-null    float64
#  12  weather_type         199 non-null    object
#  13  weather_description  199 non-null    object
# dtypes: float64(10), object(4)
# memory usage: 1.5+ MB

# %%
plt.bar(df.humidity,df.temperature)
plt.show()

# %%
sns.barplot(df['humidity'],df['temperature'])
# Out:
# C:\Users\annor\anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='humidity', ylabel='temperature'>

# %%
sns.distplot(df.humidity)
# Out:
# C:\Users\annor\anaconda3\envs\tensorflow\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='humidity', ylabel='Density'>

# %%
sns.jointplot(df.humidity, df.temperature)
# Out:
# C:\Users\annor\anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot(df.humidity, df.temperature, kind='hex')
# Out:
# C:\Users\annor\anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot(df.humidity, df.temperature, kind='hist')

# %%
sns.jointplot(df.humidity, df.temperature, kind='kde')
# Out:
# C:\Users\annor\anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.pairplot(df[['humidity','temperature','air_pollution_index']])

# %%
sns.stripplot(df.weather_type, df.temperature)
# Out:
# C:\Users\annor\anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='weather_type', ylabel='temperature'>

# %%
sns.stripplot(df.weather_type, df.temperature, jitter=True)
# Out:
# C:\Users\annor\anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='weather_type', ylabel='temperature'>

# %%
sns.boxplot(df.humidity, df.temperature, hue=df.weather_type)
# Out:
# C:\Users\annor\anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='humidity', ylabel='temperature'>

# %%
sns.barplot(df.weather_type, df.temperature,hue=df.weather_type)
# Out:
# C:\Users\annor\anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='weather_type', ylabel='temperature'>

# %%
sns.countplot(df.weather_type)
# Out:
# C:\Users\annor\anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='weather_type', ylabel='count'>

# %%
sns.pointplot(df.humidity, df.temperature,hue=df.weather_type)
# Out:
# C:\Users\annor\anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='humidity', ylabel='temperature'>

# %%
sns.lmplot(x='humidity',y='temperature', data=df)

# %%
sns.lmplot(x='humidity',y='temperature', hue='weather_type', data=df)
